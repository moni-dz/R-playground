# %% [markdown]
# # hello

# %% [markdown]
# this is my notebook

# %% [markdown]
# - R
# - Python

# %% [markdown]
# - dplyr
# - tidyverse
# - caret

# %% [markdown]
# - RStudio
# - Jupyter Notebook/Jupyterlite

# %%
1 + 1
# Out:
# [1] 2

# %%
mul <- function(a, b) {
    a * b
}

sum <- function(a, b) {
    a + b
}

mul(2, 4)
sum(1, 2)
# Out:
# [1] 3

# %%
m_to_h <- function(minutes) {
    minutes / 60
}

# %% [markdown]
# Lythe Marvin L. Lacre

# %% [markdown]
# ![{97255058-4B80-412E-8053-E0DFA3F615EF}.png](attachment:fdcbd5f9-a558-42bf-a926-0656ff37d286.png)
